# %% [markdown]
# # QAOA - 3 noeuds

# %%
# Modules
from qiskit.quantum_info import Pauli, SparsePauliOp
from itertools import combinations
from qiskit import QuantumCircuit, transpile
import numpy as np
from scipy.optimize import minimize
from functools import reduce
from qiskit.circuit.library import PauliEvolutionGate
import pylatexenc
from qiskit_aer import Aer, AerSimulator  
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt

# %% [markdown]
# il faut prendre cette contrainte en compte pour choisir les valeurs des variables: $g_i - d_i = \sum_{j, (i,j) \in L} l_{i,j}  =\sum_{j, (i,j)} l_{i,j}-\sum_{j,(j,i)}l_{j,i}$
#  $,\forall i \in B$

# %%
# exemple de valeurs

q=3 #nombre de noeuds
P_i   = [5,10,0]        # puissance générée par le noeud  
c_i   = [15,5,0]       # coût par noeud
D_i   = [2,3,4]        # demande par noeud
D_tot=np.sum(D_i)

lam=100 #pénalité
P_ij={(0,1):6, (1,2): 6, (0,2):4} #flux entre deux noeuds

# %% [markdown]
# Puisque la taille du problème a augmenté en ajoutant un 3ème noeud, le nombre de qubits nécéssaires pour le calcul a également augmenté. Pour cela, on peut penser à éliminer les contraintes qui bornent les variables dans un premier temps, et voir ensuite les 5 premières solutions les plus probables et garder celle qui respecte les bornes.

# %%
liste = list(range(q))


x_vars = [(i, j) for i in range(q) for j in range(i+1, q)]
beta_vars = [(i, m) for i in liste for m in range(9)] 

"""c_vars = [
    (i, s)
    for i in liste
    for s in range(int(np.ceil(np.log2(P_i[i])))
)
]"""


"""c_vars = []
for i in liste:
    if P_i[i] > 0:
        for s in range(int(np.ceil(np.log2(P_i[i])))):
            c_vars.append((i, s))
    else:
        c_vars.append((i, 0))  # cas si P_i[i] == 0


# c_vars2=[(i,j,p) for i in liste for j in range(i+1, q) for p in range(int(np.ceil(np.log2(P_ij[(i,j)]))))]
c_vars2=[]
for i in liste:
    for j in range(i+1, q):
        if abs(P_ij[(i,j)])>0: 
            for p in range(int(np.ceil(np.log2(abs(P_ij[(i,j)]))))): c_vars2.append((i,j,p))
            
        else: c_vars2.append((i,j,0))
        
        
#c_vars3= [(i,j,p) for i in liste for j in range(i+1, q) for p in range(int(np.ceil(np.log2(P_ij[(i,j)]))))]
c_vars3=[]
for i in liste:
    for j in range(i+1, q):
        if abs(P_ij[(i,j)])>0: 
            for p in range(int(np.ceil(np.log2(abs(P_ij[(i,j)]))))): c_vars3.append((i,j,p))
            
        else: c_vars3.append((i,j,0))"""
        
        
        
all = x_vars + beta_vars #+ c_vars + c_vars2+ c_vars3
qubit_index = {f"x_{i}_{j}": idx for idx, (i,j) in enumerate(x_vars)}
offset = len(x_vars)
for k, (i,m) in enumerate(beta_vars):
    qubit_index[f"beta_{i}_{m}"] = offset + k
    
"""offset = len(x_vars) + len(beta_vars)
for k, (i, s) in enumerate(c_vars):
    qubit_index[f"c_{i}_{s}"] = offset + k
    
offset=len(x_vars) + len(beta_vars)+ len(c_vars)
for k, (i,j,p) in enumerate (c_vars2):
    qubit_index[f"c2_{i}_{j}_{p}"]=offset+k
    
offset=len(x_vars) + len(beta_vars)+ len(c_vars)+ len(c_vars3)
for k, (i,j,p) in enumerate (c_vars3):
    qubit_index[f"c3_{i}_{j}_{p}"]=offset+k"""


n_qubit = len(all)

print("le nombre de qubits est:", n_qubit)
# Out:
# le nombre de qubits est: 30

# %%
#Pour coder les index
def idx_x(i, j):
    return qubit_index[f"x_{i}_{j}"]

def idx_beta(i, s, m):
    return qubit_index[f"beta_{i}_{m}"]

def idx_c(i,r):
    return qubit_index[f"c_{i}_{r}"]

def idx_c2(i,j,p):
    return qubit_index[f"c2_{i}_{j}_{p}"]

def idx_c3(i,j,p):
    return qubit_index[f"c3_{i}_{j}_{p}"]

# %% [markdown]
# ## Hamiltonien de coût

# %%
terms = []
B_ij = {(0,1): 1.0 }

for i in range(q):
    for j in range(i+1, q):
        if (i,j) not in B_ij:
            continue
        Bij = B_ij[(i,j)]
        for m in range(5):  # M: nombre de "modes" alpha
            for s in range(m+1,5):  # S: nombre de bits pour l'encodage binaire
                coeff = (1 / 4.0) * (2**s) * (lam + c_i[i]) * Bij * np.pi/180

                x_idx = idx_x(i,j)
                b_i_idx = idx_beta(i,s,m)
                b_j_idx = idx_beta(j,s,m)

                # - Z_x * Z_beta_j
                pauli = ['I'] * n_qubit
                pauli[x_idx] = 'Z'
                pauli[b_j_idx] = 'Z'
                terms.append((''.join(pauli), -coeff))

                # + Z_x * Z_beta_i
                pauli = ['I'] * n_qubit
                pauli[x_idx] = 'Z'
                pauli[b_i_idx] = 'Z'
                terms.append((''.join(pauli), coeff))

                # + Z_beta_j
                pauli = ['I'] * n_qubit
                pauli[b_j_idx] = 'Z'
                terms.append((''.join(pauli), coeff))

                # - Z_beta_i
                pauli = ['I'] * n_qubit
                pauli[b_i_idx] = 'Z'
                terms.append((''.join(pauli), -coeff))

# %%
for i in range(q):
    for j in range(i+1, q):
        terms.append(('I'*n_qubit, -P_ij[(i,j)]+ 2 * D_i[i]-P_i[i] ))

# %%
'''for i in range(q):
    if(P_i[i]>0):
        ki=int(np.ceil(np.log2(P_i[i] )))
    else: ki=0
    for r in range(ki):
            c_idx = idx_c(i, r)  # mapping des qubits c_{r,i}
            coeff = 2**(r-1)

            # 1 * coeff (pour le "1" dans (1 - Z))
            terms.append(('I'*n_qubit, coeff))

            # -Z_c * coeff
            pauli = ['I'] * n_qubit
            pauli[c_idx] = 'Z'
            terms.append((''.join(pauli), -coeff))'''
# Out:
# 'for i in range(q):\n    if(P_i[i]>0):\n        ki=int(np.ceil(np.log2(P_i[i] )))\n    else: ki=0\n    for r in range(ki):\n            c_idx = idx_c(i, r)  # mapping des qubits c_{r,i}\n            coeff = 2**(r-1)\n\n            # 1 * coeff (pour le "1" dans (1 - Z))\n            terms.append((\'I\'*n_qubit, coeff))\n\n            # -Z_c * coeff\n            pauli = [\'I\'] * n_qubit\n            pauli[c_idx] = \'Z\'\n            terms.append((\'\'.join(pauli), -coeff))'

# %%
'''for i in range(q):
    
    for j in range(i+1,q):
        kij=int(np.ceil(np.log2(abs(P_ij[(i,j)]))))

        for p in range(kij):
            c2_idx = idx_c2(i,j, p)  
            coeff = 2**(p-1)

            # 1 * coeff (pour le "1" dans (1 - Z))
            terms.append(('I'*n_qubit, coeff))

            # -Z_c * coeff
            pauli = ['I'] * n_qubit
            pauli[c2_idx] = 'Z'
            terms.append((''.join(pauli), -coeff))'''
# Out:
# 'for i in range(q):\n    \n    for j in range(i+1,q):\n        kij=int(np.ceil(np.log2(abs(P_ij[(i,j)]))))\n\n        for p in range(kij):\n            c2_idx = idx_c2(i,j, p)  \n            coeff = 2**(p-1)\n\n            # 1 * coeff (pour le "1" dans (1 - Z))\n            terms.append((\'I\'*n_qubit, coeff))\n\n            # -Z_c * coeff\n            pauli = [\'I\'] * n_qubit\n            pauli[c2_idx] = \'Z\'\n            terms.append((\'\'.join(pauli), -coeff))'

# %%
'''for i in range(q):
    
    for j in range(i+1,q):
        kij=int(np.ceil(np.log2(abs(P_ij[(i,j)]))))

        for p in range(kij):
            c3_idx = idx_c3(i,j, p)  
            coeff = 2**(p-1)

            terms.append(('I'*n_qubit, coeff))

            pauli = ['I'] * n_qubit
            pauli[c3_idx] = 'Z'
            terms.append((''.join(pauli), -coeff))'''
# Out:
# "for i in range(q):\n    \n    for j in range(i+1,q):\n        kij=int(np.ceil(np.log2(abs(P_ij[(i,j)]))))\n\n        for p in range(kij):\n            c3_idx = idx_c3(i,j, p)  \n            coeff = 2**(p-1)\n\n            terms.append(('I'*n_qubit, coeff))\n\n            pauli = ['I'] * n_qubit\n            pauli[c3_idx] = 'Z'\n            terms.append((''.join(pauli), -coeff))"

# %%
H_c = SparsePauliOp.from_list(terms)

# %% [markdown]
# ## Hamiltonien de mélange

# %%
H_M = SparsePauliOp.from_list([
    ('I'*i + 'X' + 'I'*(n_qubit-i-1), 1.0)
    for i in range(n_qubit)
])

print(H_M)
# Out:
# SparsePauliOp(['XIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IXIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIXIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIXIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIXIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIXIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIXIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIXIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIXIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIXIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIXIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIXIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIXIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIXIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIXIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIXIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIXIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIXIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIXIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIXIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIXIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIXIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIXIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIXIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIXIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIXIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIXIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIXII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIXI', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIX'],
#               coeffs=[1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j,
#  1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j,
#  1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j,
#  1.+0.j, 1.+0.j, 1.+0.j])

# %% [markdown]
# ## Les opérateurs d'évolution temporelle

# %%
def U_C(gamma, H):
    gate = PauliEvolutionGate(H, time=gamma)
    return gate.definition  

def U_M(beta, H):
    gate = PauliEvolutionGate(H, time=beta)
    return gate.definition

# %% [markdown]
# ## Construction du circuit QAOA

# %%
def build_qaoa_circuit(n, p, gammas, betas, cost_h, mixer_h):
    qc = QuantumCircuit(n)  
    qc.h(range(n))          
    
    for layer in range(p):
        qc.append(U_C(float(gammas[layer]), cost_h), range(n))
        qc.append(U_M(float(betas[layer]), mixer_h), range(n))
    
    return qc

# %% [markdown]
# ### Exemple du circuit QAOA

# %%
p=4 # nombre de couches
g=[np.pi/4, np.pi/2, np.pi/6, np.pi/7, np.pi/10]
gammas=g[:p]
b=[np.pi/8, np.pi/4, np.pi/3, np.pi/8, np.pi/2]
betas=b[:p]
params = gammas + betas

cost_h=H_c
mixer_h=H_M
qc2=build_qaoa_circuit(n_qubit,p,gammas,betas,cost_h,mixer_h)
qc2.measure_all()
qc2.draw("mpl")


# Affichage du résultat très long --> Plusieurs valeurs

# %% [markdown]
# ### Exemple de mesure (sans optimisation)

# %%
from qiskit import transpile

sim = AerSimulator(method='matrix_product_state')

qc_transpiled2 = transpile(qc2, sim)
job = sim.run(qc_transpiled2, shots=1024)
result = job.result()
counts = result.get_counts()
plot_histogram(counts)

# %%
"""#la mesure
qc_transpiled2 = transpile(qc2, AerSimulator())

job = AerSimulator().run(qc_transpiled2, shots=1024)
result = job.result()
counts = result.get_counts()

plot_histogram(counts)
"""

# %%
from qiskit_aer import AerSimulator
sim = AerSimulator()
print(sim.available_devices())
# Out:
# ('CPU',)

# %% [markdown]
# ### utilisation de qisikit.quantuminfo simulator

# %%
from qiskit.quantum_info import Statevector

# Récupération du statevector directement depuis le circuit
statevector = Statevector.from_instruction(qc2)

# Conversion en probabilités
counts = statevector.probabilities_dict()

plot_histogram(counts)

# %% [markdown]
# ## Définition de la fonction objectif

# %%
from qiskit import transpile
from qiskit_aer import Aer
import numpy as np
from scipy.optimize import minimize

backend = Aer.get_backend('aer_simulator')

def qaoa_expectation(params):
    gammas = params[:p]
    betas = params[p:]
    
    qc2 = build_qaoa_circuit(n_qubit, p, gammas, betas, H_c, H_M)
    qc2.save_statevector()
    
    qc_transpiled = transpile(qc2, backend)
    result = backend.run(qc_transpiled).result()
    
    sv = result.data(0)['statevector']
    expval = sv.expectation_value(H_c)
    return np.real(expval)

# %% [markdown]
# ## Optimisation --> Garder les 5 premières solutions

# %%
import time

p=2
g=[np.pi/4, np.pi/2, np.pi/6, np.pi/7, np.pi/10]
gammas=g[:p]
b=[np.pi/8, np.pi/4, np.pi/3, np.pi/8, np.pi/2]
betas=b[:p]
params = gammas + betas # à changer par concatenation !!
start = time.time()

#mesure
result = minimize(qaoa_expectation, params, method='COBYLA')

print("Paramètres optimaux :", result.x)
print("Espérance d'énergie minimale :", -result.fun)

# Circuit avec les paramètres optimaux

gammas=result.x[:p]
betas=result.x[p:]

qc3 = build_qaoa_circuit(n_qubit,p, gammas,betas,cost_h,mixer_h)
qc3.measure_all()
qc_transpiled3 = transpile(qc3, AerSimulator())

job = AerSimulator().run(qc_transpiled3, shots=1024)
result_new = job.result()
counts_new = result_new.get_counts()


end = time.time()
print("Temps d'exécution :", end - start, "secondes")
# Out:
# ---------------------------------------------------------------------------
# CircuitTooWideForTarget                   Traceback (most recent call last)
# Cell In[37], line 12
#       9 start = time.time()
#      11 #mesure
# ---> 12 result = minimize(qaoa_expectation, params, method='COBYLA')
#      14 print("Paramètres optimaux :", result.x)
#      15 print("Espérance d'énergie minimale :", -result.fun)
#
# File c:\Users\TACHI\anaconda3\envs\qiskit-env\lib\site-packages\scipy\optimize\_minimize.py:744, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     741     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     742                         **options)
#     743 elif meth == 'cobyla':
# --> 744     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     745                            bounds=bounds, **options)
#     746 elif meth == 'cobyqa':
#     747     res = _minimize_cobyqa(fun, x0, args, bounds, constraints, callback,
#     748                            **options)
#
# File c:\Users\TACHI\anaconda3\envs\qiskit-env\lib\site-packages\scipy\optimize\_cobyla_py.py:35, in synchronized.<locals>.wrapper(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def wrapper(*args, **kwargs):
#      34     with _module_lock:
# ---> 35         return func(*args, **kwargs)
#
# File c:\Users\TACHI\anaconda3\envs\qiskit-env\lib\site-packages\scipy\optimize\_cobyla_py.py:278, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, callback, bounds, **unknown_options)
#     275 def _jac(x, *args):
#     276     return None
# --> 278 sf = _prepare_scalar_function(fun, x0, args=args, jac=_jac)
#     280 def calcfc(x, con):
#     281     f = sf.fun(x)
#
# File c:\Users\TACHI\anaconda3\envs\qiskit-env\lib\site-packages\scipy\optimize\_optimize.py:291, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     287     bounds = (-np.inf, np.inf)
#     289 # ScalarFunction caches. Reuse of fun(x) during grad
#     290 # calculation reduces overall function evaluations.
# --> 291 sf = ScalarFunction(fun, x0, args, grad, hess,
#     292                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     294 return sf
#
# File c:\Users\TACHI\anaconda3\envs\qiskit-env\lib\site-packages\scipy\optimize\_differentiable_functions.py:223, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     220     finite_diff_options["as_linear_operator"] = True
#     222 # Initial function evaluation
# --> 223 self._update_fun()
#     225 # Initial gradient evaluation
#     226 self._wrapped_grad, self._ngev = _wrapper_grad(
#     227     grad,
#     228     fun=self._wrapped_fun,
#     229     args=args,
#     230     finite_diff_options=finite_diff_options
#     231 )
#
# File c:\Users\TACHI\anaconda3\envs\qiskit-env\lib\site-packages\scipy\optimize\_differentiable_functions.py:295, in ScalarFunction._update_fun(self)
#     293 def _update_fun(self):
#     294     if not self.f_updated:
# --> 295         fx = self._wrapped_fun(self.x)
#     296         if fx < self._lowest_f:
#     297             self._lowest_x = self.x
#
# File c:\Users\TACHI\anaconda3\envs\qiskit-env\lib\site-packages\scipy\optimize\_differentiable_functions.py:21, in _wrapper_fun.<locals>.wrapped(x)
#      17 ncalls[0] += 1
#      18 # Send a copy because the user may overwrite it.
#      19 # Overwriting results in undefined behaviour because
#      20 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 21 fx = fun(np.copy(x), *args)
#      22 # Make sure the function returns a true scalar
#      23 if not np.isscalar(fx):
#
# Cell In[36], line 15, in qaoa_expectation(params)
#      12 qc2 = build_qaoa_circuit(n_qubit, p, gammas, betas, H_c, H_M)
#      13 qc2.save_statevector()
# ---> 15 qc_transpiled = transpile(qc2, backend)
#      16 result = backend.run(qc_transpiled).result()
#      18 sv = result.data(0)['statevector']
#
# File c:\Users\TACHI\anaconda3\envs\qiskit-env\lib\site-packages\qiskit\compiler\transpiler.py:264, in transpile(circuits, backend, basis_gates, coupling_map, initial_layout, layout_method, routing_method, translation_method, scheduling_method, dt, approximation_degree, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target, hls_config, init_method, optimization_method, ignore_backend_supplied_default_methods, num_processes, qubits_initially_zero)
#     262 output_name = _parse_output_name(output_name, circuits)
#     263 coupling_map = _parse_coupling_map(coupling_map)
# --> 264 _check_circuits_coupling_map(circuits, coupling_map, backend)
#     266 # Edge cases require using the old model (loose constraints) instead of building a target,
#     267 # but we don't populate the passmanager config with loose constraints unless it's one of
#     268 # the known edge cases to control the execution path.
#     269 pm = generate_preset_pass_manager(
#     270     optimization_level,
#     271     target=target,
#    (...)
#     288     qubits_initially_zero=qubits_initially_zero,
#     289 )
#
# File c:\Users\TACHI\anaconda3\envs\qiskit-env\lib\site-packages\qiskit\compiler\transpiler.py:315, in _check_circuits_coupling_map(circuits, cmap, backend)
#     313 num_qubits = len(circuit.qubits)
#     314 if max_qubits is not None and (num_qubits > max_qubits):
# --> 315     raise CircuitTooWideForTarget(
#     316         f"Number of qubits ({num_qubits}) in {circuit.name} "
#     317         f"is greater than maximum ({max_qubits}) in the coupling_map"
#     318     )
#
# CircuitTooWideForTarget: 'Number of qubits (30) in circuit-211 is greater than maximum (29) in the coupling_map'

# %%
import os
# Trier les bitstrings par nombre d’occurrences décroissant
top_5 = sorted(counts.items(), key=lambda item: item[1], reverse=True)[:10]

with open("resultats_qaoa.txt", "w", encoding="utf-8") as f:
    f.write("Top 5 des bitstrings les plus probables :\n")
    
    for bitstring, count in top_5:
        f.write(f"{bitstring} → {count} fois\n")
        
        inv_index = {v: k for k, v in qubit_index.items()}  # j’inverse le dict

        bit_values = {}
        for i, bit in enumerate(reversed(bitstring)):
            var_name = inv_index[i]
            bit_values[var_name] = int(bit)

        x_values = {k: v for k, v in bit_values.items() if k.startswith("x_")}
        beta_values = {k: v for k, v in bit_values.items() if k.startswith("beta_")}

        for var_group, values in [("x_vars", x_values), ("beta_vars", beta_values)]:
            f.write(f"{var_group}:\n")
            for var, val in sorted(values.items()):
                f.write(f"  {var} = {val}\n")
                
        for var_group, values in [("beta_vars", beta_values)]:
            f.write(f"{var_group}:")

    # Séparer selon le deuxième champ cad : beta_0_i ou beta_1_i
    
        half0 = {k: v for k, v in values.items() if k.startswith("beta_0_")}
        half1 = {k: v for k, v in values.items() if k.startswith("beta_1_")}
        for label, group in [("beta_0", half0), ("beta_1", half1)]:
                total = 0
                for var, val in sorted(group.items(), key=lambda x: int(x[0].split("_")[-1])):
                    bit_pos = int(var.split("_")[-1])
                    contrib = val * (2 ** bit_pos)
                    total += contrib
        f.write(f"    --> Donc: theta = {total}\n")

        
        f.write("Autre possibilité:\n\n")
        

with open("resultats_qaoa.txt", "r", encoding="utf_8") as f:
    print(f.read())
    
os.system("resultats_qaoa.txt")
# Out:
# Top 5 des bitstrings les plus probables :
# 100100100110100000011110000011 → 1 fois
# x_vars:
#   x_0_1 = 1
#   x_0_2 = 1
#   x_1_2 = 0
# beta_vars:
#   beta_0_0 = 0
#   beta_0_1 = 0
#   beta_0_2 = 0
#   beta_0_3 = 0
#   beta_0_4 = 1
#   beta_0_5 = 1
#   beta_0_6 = 1
#   beta_0_7 = 1
#   beta_0_8 = 0
#   beta_1_0 = 0
#   beta_1_1 = 0
#   beta_1_2 = 0
#   beta_1_3 = 0
#   beta_1_4 = 0
#   beta_1_5 = 1
#   beta_1_6 = 0
#   beta_1_7 = 1
#   beta_1_8 = 1
#   beta_2_0 = 0
#   beta_2_1 = 0
#   beta_2_2 = 1
#   beta_2_3 = 0
#   beta_2_4 = 0
#   beta_2_5 = 1
#   beta_2_6 = 0
#   beta_2_7 = 0
#   beta_2_8 = 1
# beta_vars:    --> Donc: theta = 416
# Autre possibilité:
#
# 011111010111000100001001010000 → 1 fois
# x_vars:
#   x_0_1 = 0
#   x_0_2 = 0
#   x_1_2 = 0
# beta_vars:
#   beta_0_0 = 0
#   beta_0_1 = 1
#   beta_0_2 = 0
#   beta_0_3 = 1
#   beta_0_4 = 0
#   beta_0_5 = 0
#   beta_0_6 = 1
#   beta_0_7 = 0
#   beta_0_8 = 0
#   beta_1_0 = 0
#   beta_1_1 = 0
#   beta_1_2 = 1
#   beta_1_3 = 0
#   beta_1_4 = 0
#   beta_1_5 = 0
#   beta_1_6 = 1
#   beta_1_7 = 1
#   beta_1_8 = 1
#   beta_2_0 = 0
#   beta_2_1 = 1
#   beta_2_2 = 0
#   beta_2_3 = 1
#   beta_2_4 = 1
#   beta_2_5 = 1
#   beta_2_6 = 1
#   beta_2_7 = 1
#   beta_2_8 = 0
# beta_vars:    --> Donc: theta = 452
# Autre possibilité:
#
# 010011111111100010000100100010 → 1 fois
# x_vars:
#   x_0_1 = 0
#   x_0_2 = 1
#   x_1_2 = 0
# beta_vars:
#   beta_0_0 = 0
#   beta_0_1 = 0
#   beta_0_2 = 1
#   beta_0_3 = 0
#   beta_0_4 = 0
#   beta_0_5 = 1
#   beta_0_6 = 0
#   beta_0_7 = 0
#   beta_0_8 = 0
#   beta_1_0 = 0
#   beta_1_1 = 1
#   beta_1_2 = 0
#   beta_1_3 = 0
#   beta_1_4 = 0
#   beta_1_5 = 1
#   beta_1_6 = 1
#   beta_1_7 = 1
#   beta_1_8 = 1
#   beta_2_0 = 1
#   beta_2_1 = 1
#   beta_2_2 = 1
#   beta_2_3 = 1
#   beta_2_4 = 1
#   beta_2_5 = 0
#   beta_2_6 = 0
#   beta_2_7 = 1
#   beta_2_8 = 0
# beta_vars:    --> Donc: theta = 482
# Autre possibilité:
#
# 111101101001101001011100100010 → 1 fois
# x_vars:
#   x_0_1 = 0
#   x_0_2 = 1
#   x_1_2 = 0
# beta_vars:
#   beta_0_0 = 0
#   beta_0_1 = 0
#   beta_0_2 = 1
#   beta_0_3 = 0
#   beta_0_4 = 0
#   beta_0_5 = 1
#   beta_0_6 = 1
#   beta_0_7 = 1
#   beta_0_8 = 0
#   beta_1_0 = 1
#   beta_1_1 = 0
#   beta_1_2 = 0
#   beta_1_3 = 1
#   beta_1_4 = 0
#   beta_1_5 = 1
#   beta_1_6 = 1
#   beta_1_7 = 0
#   beta_1_8 = 0
#   beta_2_0 = 1
#   beta_2_1 = 0
#   beta_2_2 = 1
#   beta_2_3 = 1
#   beta_2_4 = 0
#   beta_2_5 = 1
#   beta_2_6 = 1
#   beta_2_7 = 1
#   beta_2_8 = 1
# beta_vars:    --> Donc: theta = 105
# Autre possibilité:
#
# 011101100001010001101001000100 → 1 fois
# x_vars:
#   x_0_1 = 0
#   x_0_2 = 0
#   x_1_2 = 1
# beta_vars:
#   beta_0_0 = 0
#   beta_0_1 = 0
#   beta_0_2 = 0
#   beta_0_3 = 1
#   beta_0_4 = 0
#   beta_0_5 = 0
#   beta_0_6 = 1
#   beta_0_7 = 0
#   beta_0_8 = 1
#   beta_1_0 = 1
#   beta_1_1 = 0
#   beta_1_2 = 0
#   beta_1_3 = 0
#   beta_1_4 = 1
#   beta_1_5 = 0
#   beta_1_6 = 1
#   beta_1_7 = 0
#   beta_1_8 = 0
#   beta_2_0 = 0
#   beta_2_1 = 0
#   beta_2_2 = 1
#   beta_2_3 = 1
#   beta_2_4 = 0
#   beta_2_5 = 1
#   beta_2_6 = 1
#   beta_2_7 = 1
#   beta_2_8 = 0
# beta_vars:    --> Donc: theta = 81
# Autre possibilité:
#
# 110011101111000000110010101100 → 1 fois
# x_vars:
#   x_0_1 = 0
#   x_0_2 = 0
#   x_1_2 = 1
# beta_vars:
#   beta_0_0 = 1
#   beta_0_1 = 0
#   beta_0_2 = 1
#   beta_0_3 = 0
#   beta_0_4 = 1
#   beta_0_5 = 0
#   beta_0_6 = 0
#   beta_0_7 = 1
#   beta_0_8 = 1
#   beta_1_0 = 0
#   beta_1_1 = 0
#   beta_1_2 = 0
#   beta_1_3 = 0
#   beta_1_4 = 0
#   beta_1_5 = 0
#   beta_1_6 = 1
#   beta_1_7 = 1
#   beta_1_8 = 1
#   beta_2_0 = 1
#   beta_2_1 = 0
#   beta_2_2 = 1
#   beta_2_3 = 1
#   beta_2_4 = 1
#   beta_2_5 = 0
#   beta_2_6 = 0
#   beta_2_7 = 1
#   beta_2_8 = 1
# beta_vars:    --> Donc: theta = 448
# Autre possibilité:
#
# 100010001100010010011001111110 → 1 fois
# x_vars:
#   x_0_1 = 0
#   x_0_2 = 1
#   x_1_2 = 1
# beta_vars:
#   beta_0_0 = 1
#   beta_0_1 = 1
#   beta_0_2 = 1
#   beta_0_3 = 1
#   beta_0_4 = 0
#   beta_0_5 = 0
#   beta_0_6 = 1
#   beta_0_7 = 1
#   beta_0_8 = 0
#   beta_1_0 = 0
#   beta_1_1 = 1
#   beta_1_2 = 0
#   beta_1_3 = 0
#   beta_1_4 = 1
#   beta_1_5 = 0
#   beta_1_6 = 0
#   beta_1_7 = 0
#   beta_1_8 = 1
#   beta_2_0 = 1
#   beta_2_1 = 0
#   beta_2_2 = 0
#   beta_2_3 = 0
#   beta_2_4 = 1
#   beta_2_5 = 0
#   beta_2_6 = 0
#   beta_2_7 = 0
#   beta_2_8 = 1
# beta_vars:    --> Donc: theta = 274
# Autre possibilité:
#
# 100111001100011101000100000000 → 1 fois
# x_vars:
#   x_0_1 = 0
#   x_0_2 = 0
#   x_1_2 = 0
# beta_vars:
#   beta_0_0 = 0
#   beta_0_1 = 0
#   beta_0_2 = 0
#   beta_0_3 = 0
#   beta_0_4 = 0
#   beta_0_5 = 1
#   beta_0_6 = 0
#   beta_0_7 = 0
#   beta_0_8 = 0
#   beta_1_0 = 1
#   beta_1_1 = 0
#   beta_1_2 = 1
#   beta_1_3 = 1
#   beta_1_4 = 1
#   beta_1_5 = 0
#   beta_1_6 = 0
#   beta_1_7 = 0
#   beta_1_8 = 1
#   beta_2_0 = 1
#   beta_2_1 = 0
#   beta_2_2 = 0
#   beta_2_3 = 1
#   beta_2_4 = 1
#   beta_2_5 = 1
#   beta_2_6 = 0
#   beta_2_7 = 0
#   beta_2_8 = 1
# beta_vars:    --> Donc: theta = 285
# Autre possibilité:
#
# 110001001011010010101100101101 → 1 fois
# x_vars:
#   x_0_1 = 1
#   x_0_2 = 0
#   x_1_2 = 1
# beta_vars:
#   beta_0_0 = 1
#   beta_0_1 = 0
#   beta_0_2 = 1
#   beta_0_3 = 0
#   beta_0_4 = 0
#   beta_0_5 = 1
#   beta_0_6 = 1
#   beta_0_7 = 0
#   beta_0_8 = 1
#   beta_1_0 = 0
#   beta_1_1 = 1
#   beta_1_2 = 0
#   beta_1_3 = 0
#   beta_1_4 = 1
#   beta_1_5 = 0
#   beta_1_6 = 1
#   beta_1_7 = 1
#   beta_1_8 = 0
#   beta_2_0 = 1
#   beta_2_1 = 0
#   beta_2_2 = 0
#   beta_2_3 = 1
#   beta_2_4 = 0
#   beta_2_5 = 0
#   beta_2_6 = 0
#   beta_2_7 = 1
#   beta_2_8 = 1
# beta_vars:    --> Donc: theta = 210
# Autre possibilité:
#
# 101010100111001000010011111010 → 1 fois
# x_vars:
#   x_0_1 = 0
#   x_0_2 = 1
#   x_1_2 = 0
# beta_vars:
#   beta_0_0 = 1
#   beta_0_1 = 1
#   beta_0_2 = 1
#   beta_0_3 = 1
#   beta_0_4 = 1
#   beta_0_5 = 0
#   beta_0_6 = 0
#   beta_0_7 = 1
#   beta_0_8 = 0
#   beta_1_0 = 0
#   beta_1_1 = 0
#   beta_1_2 = 0
#   beta_1_3 = 1
#   beta_1_4 = 0
#   beta_1_5 = 0
#   beta_1_6 = 1
#   beta_1_7 = 1
#   beta_1_8 = 1
#   beta_2_0 = 0
#   beta_2_1 = 0
#   beta_2_2 = 1
#   beta_2_3 = 0
#   beta_2_4 = 1
#   beta_2_5 = 0
#   beta_2_6 = 1
#   beta_2_7 = 0
#   beta_2_8 = 1
# beta_vars:    --> Donc: theta = 456
# Autre possibilité:
# 0

# %%
from gurobipy import Model, GRB

# Données
nodes = [0, 1,2]
P_min = {0: 0, 1: 0, 2:0}
P_max = {0: 5, 1: 10, 2: 0}
c = {0: 15, 1: 5, 2:0}
d = {0: 2, 1: 3, 2:4}

lines = [(0,1), (1,2), (0,2)]
L_max = {(0,1): 6, (1,2): 6, (0,2): 4}
B = {(0,1): 1.0, (1,2): 1, (0,2):1}  # susceptance
X = {(0,1): 1.0 / B[(0,1)], (1,2): 1.0 / B[(1,2)], (0,2): 1.0 / B[(0,2)] }  # reactance

# Modèle
m = Model("OTS")
m.setParam('OutputFlag', 0) # pour n'afficher que le résultat final (sans détails)


# Variables
g = m.addVars(nodes, lb=0, ub=GRB.INFINITY, name="g")
l = m.addVars(lines, lb=-GRB.INFINITY, ub=GRB.INFINITY, name="l")
theta = m.addVars(nodes, lb=-GRB.INFINITY, ub=GRB.INFINITY, name="theta")
delta = m.addVars(lines, vtype=GRB.BINARY, name="delta")

# Contraintes

# Puissance générée bornée
for i in nodes:
    m.addConstr(g[i] >= P_min[i], name=f"Pmin_{i}")
    m.addConstr(g[i] <= P_max[i], name=f"Pmax_{i}")
    
m.addConstr(theta[0] == 0, name="ref_angle")


# Équilibre puissance au noeud : g_i - d_i = somme l_ij
# Ici flux antisymétrique: l_ji = - l_ij, on fait ça en calculant somme flux sortants
for i in nodes:
    flux_sum = 0
    for (u,v) in lines:
        if u == i:
            flux_sum += l[(u,v)]
        elif v == i:
            flux_sum -= l[(u,v)]
    m.addConstr(g[i] - d[i] == flux_sum, name=f"balance_{i}")

# Limites sur les flux avec delta (ligne ouverte ou fermée)
for (i,j) in lines:
    m.addConstr(l[(i,j)] <= L_max[(i,j)] * delta[(i,j)], name=f"flux_pos_{i}_{j}")
    m.addConstr(l[(i,j)] >= -L_max[(i,j)] * delta[(i,j)], name=f"flux_neg_{i}_{j}")

# Flux selon approximation DC : l_ij = delta_ij * (theta_i - theta_j) / X_ij
# Modèle linéaire avec delta * (theta_i - theta_j)
# Implémentation avec contraintes de "Big M"
M = 10000  # grand nombre pour activer/désactiver contraintes

for (i,j) in lines:
    m.addConstr(l[(i,j)] <= (theta[i] - theta[j]) / X[(i,j)] + M * (1 - delta[(i,j)]), name=f"dc_pos_{i}_{j}")
    m.addConstr(l[(i,j)] >= (theta[i] - theta[j]) / X[(i,j)] - M * (1 - delta[(i,j)]), name=f"dc_neg_{i}_{j}")
    m.addConstr(l[(i,j)] <= L_max[(i,j)], name=f"cap_pos_{i}_{j}")
    m.addConstr(l[(i,j)] >= -L_max[(i,j)], name=f"cap_neg_{i}_{j}")

# Objectif : minimiser le coût total
m.setObjective(sum(c[i]*g[i] for i in nodes), GRB.MINIMIZE)

# Résolution
m.optimize()

# Affichage des résultats
if m.status == GRB.OPTIMAL:
    print("Solution optimale trouvée:")
    for i in nodes:
        print(f"g[{i}] = {g[i].X:.2f}")
    for (i,j) in lines:
        print(f"delta[{i},{j}] = {delta[(i,j)].X}")
        print(f"l[{i},{j}] = {l[(i,j)].X:.2f}")
        print(f"theta[{i}] = {theta[i].X:.2f}")
else:
    print("Pas de solution optimale trouvée.")

print(theta)
# Out:
# Solution optimale trouvée:
# g[0] = 0.00
# g[1] = 9.00
# g[2] = 0.00
# delta[0,1] = -0.0
# l[0,1] = 0.00
# theta[0] = 0.00
# delta[1,2] = 1.0
# l[1,2] = 6.00
# theta[1] = 8.00
# delta[0,2] = 1.0
# l[0,2] = -2.00
# theta[0] = 0.00
# {0: <gurobi.Var theta[0] (value 0.0)>, 1: <gurobi.Var theta[1] (value 8.0)>, 2: <gurobi.Var theta[2] (value 2.0)>}
